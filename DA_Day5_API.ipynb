# %% [markdown]
# Random Fox API

# %%
import requests

# %%
page=requests.get('https://randomfox.ca/floof')

# %%
print(page.status_code)
# Out:
# 200

# %%
print(page.text)
# Out:
# {"image":"https:\/\/randomfox.ca\/images\/23.jpg","link":"https:\/\/randomfox.ca\/?i=23"}

# %%
print(page.json())
# Out:
# {'image': 'https://randomfox.ca/images/23.jpg', 'link': 'https://randomfox.ca/?i=23'}

# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'5000',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '18cf5034-0f93-441b-8162-c53204f7fb04',

}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'status': {'timestamp': '2024-02-16T09:49:24.325Z', 'error_code': 0, 'error_message': None, 'elapsed': 1, 'credit_count': 1, 'notice': None}, 'data': [{'id': 800, 'name': 'y63lxexsuw8', 'symbol': 'k0933fer5a', 'slug': 'atk52fyh7zg', 'cmc_rank': 3721, 'num_market_pairs': 8218, 'circulating_supply': 2252, 'total_supply': 4839, 'max_supply': 8144, 'infinite_supply': None, 'last_updated': '2024-02-16T09:49:24.325Z', 'date_added': '2024-02-16T09:49:24.325Z', 'tags': ['i09at7o3ag', 'pxy2ranyr7', 'alkl1lepy4', '3vvi1h36pyq', 'tgc1f7446w', 'cwbm86jls0g', 'tm6ixpoy1i', 'gk01e06hch', 'l6j4nhsl4eo', 'oabpad66xjs'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'USD': {'price': 0.011570360913649491, 'volume_24h': 2793, 'volume_change_24h': 0.1778997667197446, 'percent_change_1h': 0.5738108121157488, 'percent_change_24h': 0.6412255891056482, 'percent_change_7d': 0.9008135573707474, 'market_cap': 0.6623214386366891, 'market_cap_dominance': 484, 'fully_diluted_market_cap': 0.6870079088081957, 'last_updated': '2024-02-16T09:49:24.325Z'}}}, {'id': 9727, 'name': 'm8v3v6824a', 'symbol': '65ngus3sqe', 'slug': 'g0vle3g046q', 'cmc_rank': 6735, 'num_market_pairs': 1673, 'circulating_supply': 224, 'total_supply': 7637, 'max_supply': 7470, 'infinite_supply': None, 'last_updated': '2024-02-16T09:49:24.325Z', 'date_added': '2024-02-16T09:49:24.325Z', 'tags': ['yk6xdmxfyxc', 'mofjsajeo1g', 'sazt7t1kejs', 'nfgyoqm00qi', '0gf23124lvfa', 'goarn0gdtob', '6f2ync830c', 'zvzb5u8oqq8', 'irktswrtvn', 's9qgzqkda5'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'USD': {'price': 0.5867475095712407, 'volume_24h': 9147, 'volume_change_24h': 0.2600922875780083, 'percent_change_1h': 0.8542128140466028, 'percent_change_24h': 0.12807091742040022, 'percent_change_7d': 0.45309669226601357, 'market_cap': 0.4937865945385178, 'market_cap_dominance': 6704, 'fully_diluted_market_cap': 0.03344355396733345, 'last_updated': '2024-02-16T09:49:24.325Z'}}}, {'id': 7107, 'name': 'twa6mmmy2s', 'symbol': 'vgt1ekd8qeo', 'slug': '7ywaem42wc', 'cmc_rank': 6346, 'num_market_pairs': 7308, 'circulating_supply': 8176, 'total_supply': 5599, 'max_supply': 8883, 'infinite_supply': None, 'last_updated': '2024-02-16T09:49:24.325Z', 'date_added': '2024-02-16T09:49:24.325Z', 'tags': ['1rxpqedk2ro', 'a74rdmaql3f', 'e37g0unproa', 'drlwpecr8mm', '72qvm3etv4k', 'cb17zy66kob', '3mbhdz1ggos', 'dyhz5if1v9o', 'p5z11jfzzqo', 'huamebrh2t'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'USD': {'price': 0.009843922540109018, 'volume_24h': 2643, 'volume_change_24h': 0.7541075349700632, 'percent_change_1h': 0.6519626548048074, 'percent_change_24h': 0.8675350816861558, 'percent_change_7d': 0.9225992657566902, 'market_cap': 0.5625277320950219, 'market_cap_dominance': 6454, 'fully_diluted_market_cap': 0.9843747386589132, 'last_updated': '2024-02-16T09:49:24.325Z'}}}, {'id': 4676, 'name': 'ho33j1d9pmd', 'symbol': '7x5gnj4y1zm', 'slug': 'la0nob5ztc', 'cmc_rank': 8231, 'num_market_pairs': 8271, 'circulating_supply': 3223, 'total_supply': 1541, 'max_supply': 221, 'infinite_supply': None, 'last_updated': '2024-02-16T09:49:24.325Z', 'date_added': '2024-02-16T09:49:24.325Z', 'tags': ['0duzvwrgifr8', '4lfl8yz9ila', '3a5z62221wi', 'ycfiogftnbh', '45e0ys8rm2p', '52plyuybyt9', 'n93y4id4ghi', 'vrlqba71em', '75s2ansbm25', 'c182rewv5vj'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'USD': {'price': 0.6456634710527978, 'volume_24h': 5466, 'volume_change_24h': 0.23181201051538491, 'percent_change_1h': 0.43118868714005876, 'percent_change_24h': 0.3354085688025994, 'percent_change_7d': 0.6331626892385405, 'market_cap': 0.43590850772385026, 'market_cap_dominance': 7664, 'fully_diluted_market_cap': 0.023037872405862414, 'last_updated': '2024-02-16T09:49:24.325Z'}}}, {'id': 6014, 'name': 'nif1z3x14nf', 'sy ...

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd
norm=pd.json_normalize(data['data'])

# %%
norm
# Out:
#      id         name       symbol          slug  cmc_rank  num_market_pairs  \
# 0   800  y63lxexsuw8   k0933fer5a   atk52fyh7zg      3721              8218
# 1  9727   m8v3v6824a   65ngus3sqe   g0vle3g046q      6735              1673
# 2  7107   twa6mmmy2s  vgt1ekd8qeo    7ywaem42wc      6346              7308
# 3  4676  ho33j1d9pmd  7x5gnj4y1zm    la0nob5ztc      8231              8271
# 4  6014  nif1z3x14nf   wazi53bwzj   vhwwzx5ynpk      6664              2767
# 5  3598  7x563pwcwov   mz40yv6dbz   pqvhh1itftd      6982              5376
# 6  8685  i4hxdffss79  u775an2qksi    tqxxxjv4xa      1781              9857
# 7  8341  9e6wkkerpf9  sma5gqjuava   rusigz68ecm      2706              3157
# 8   764  eol82v48r1v  v1tagxthqig   11o9ly9g3rb      4679              7739
# 9  3784   y3zk6k7d42  nxgc97dlues  0f3mjklvprsd      7054              2659
#
#    circulating_supply  total_supply  max_supply infinite_supply  ...  \
# 0                2252          4839        8144            None  ...
# 1                 224          7637        7470            None  ...
# 2                8176          5599        8883            None  ...
# 3                3223          1541         221            None  ...
# 4                4651          7875        9261            None  ...
# 5                5093          6352        2241            None  ...
# 6                5295          4116         590            None  ...
# 7                7624          5571        6275            None  ...
# 8                8671          2511        2857            None  ...
# 9                5926          3526        7122            None  ...
#
#   quote.USD.price quote.USD.volume_24h quote.USD.volume_change_24h  \
# 0        0.011570                 2793                    0.177900
# 1        0.586748                 9147                    0.260092
# 2        0.009844                 2643                    0.754108
# 3        0.645663                 5466                    0.231812
# 4        0.870854                 5889                    0.636629
# 5        0.211050                 7594                    0.762500
# 6        0.766139                 5577                    0.015757
# 7        0.190145                 6877                    0.742715
# 8        0.817550                 7089                    0.980763
# 9        0.062829                  672                    0.229692
#
#   quote.USD.percent_change_1h quote.USD.percent_change_24h  \
# 0                    0.573811                     0.641226
# 1                    0.854213                     0.128071
# 2                    0.651963                     0.867535
# 3                    0.431189                     0.335409
# 4                    0.494480                     0.167459
# 5                    0.577667                     0.652737
# 6                    0.485281                     0.466219
# 7                    0.383533                     0.517867
# 8                    0.676229                     0.400944
# 9                    0.256105                     0.992613
#
#   quote.USD.percent_change_7d  quote.USD.market_cap  \
# 0                    0.900814              0.662321
# 1                    0.453097              0.493787
# 2                    0.922599              0.562528
# 3                    0.633163              0.435909
# 4                    0.879596              0.137930
# 5                    0.163747              0.549439
# 6                    0.814479              0.499546
# 7                    0.965539              0.850432
# 8                    0.881658              0.500750
# 9                    0.400189              0.261874
#
#    quote.USD.market_cap_dominance  quote.USD.fully_diluted_market_cap  \
# 0                             484                            0.687008
# 1                            6704                            0.033444
# 2                            6454                            0.984375
# 3                            7664                            0.023038
# 4                            7766                            0.034506
# 5                            3715                            0.452341
# 6                            2761                            0.482918
# 7                            3438                            0.178305
# 8                            4895                            0.187965
# 9                            8816                            0.099782
#
#      quote.USD.last_updated
# 0  2024-02-16T09:49:24.325Z
# 1  2024-02-16T09:49:24.325Z
# 2  2024-02-16T09:49:24.325Z
# 3  2024-02-16T09:49:24.325Z
# 4  2024-02-16T09:49:24.325Z
# 5  2024-02-16T09:49:24.325Z
# 6  2024-02-16T09:49:24.325Z
# 7  2024-02-16T09:49:24.325Z
# 8  2024-02-16T09:49:24.325Z
# 9  2024-02-16T09:49:24.325Z
#
# [10 rows x 26 columns]
